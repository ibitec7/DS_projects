# %%
from PIL import Image
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from sklearn.preprocessing import minmax_scale

# %%
nigga=Image.open('/home/ibrahim/Downloads/img/20210822_135230.jpg')
niggi=Image.open('/home/ibrahim/Downloads/img/20210417_211802.jpg')

# %%
transform=transforms.Compose([
    transforms.PILToTensor()
])

# %%
NIGGA=transform(nigga)
NIGGI=transform(niggi)

# %%
NIGGA=NIGGA.permute(1,2,0)
NIGGI=NIGGI.permute(1,2,0)

# %% [markdown]
# # for i in range(0,3):
# #     NIGGA[:,:,i]=torch.Tensor(minmax_scale(NIGGA[:,:,i],feature_range=(0,1)))

# %% [markdown]
# # NIGGA[:,:,1]*=0.8

# %%
plt.matshow(NIGGA[:,:,0],cmap='Reds')
plt.title('Red NIGGA')
plt.colorbar()
plt.show()

# %%
plt.matshow(NIGGA[:,:,1],cmap='Blues')
plt.title('Blue NIGGA')
plt.colorbar()
plt.show()

# %%
plt.matshow(NIGGA[:,:,2],cmap='Greens')
plt.title('Green NIGGA')
plt.colorbar()
plt.show()

# %%
import cv2

# %%
NIGGA=NIGGA.unsqueeze(dim=0)

# %%
NIGGA.shape
# Out:
# torch.Size([1, 3468, 3468, 3])

# %%
import torch
import torch.nn as nn

# Create a sample input tensor (batch_size, channels, height, width)
input_tensor = NIGGA

# Create a convolutional layer with specified input and output channels, kernel size, and padding
conv_layer = nn.Conv2d(in_channels=3468, out_channels=32, kernel_size=3, padding=1)

# Perform the convolution operation
output = conv_layer(input_tensor)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 11
#       8 conv_layer = nn.Conv2d(in_channels=3468, out_channels=32, kernel_size=3, padding=1)
#      10 # Perform the convolution operation
# ---> 11 output = conv_layer(input_tensor)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
# ...

# %%
NIGGA=NIGGA.squeeze()

# %%
plt.imshow(NIGGA[:,:,:])
plt.title('FULL NIGGA')
plt.colorbar()
plt.show()

# %%
plt.matshow(NIGGI[:,:,0],cmap='Reds')
plt.title('Red NIGGI')
plt.colorbar()
plt.show()

# %%
plt.matshow(NIGGI[:,:,1],cmap='Blues')
plt.title('Blue NIGGI')
plt.colorbar()
plt.show()

# %%
plt.matshow(NIGGI[:,:,2],cmap='Greens')
plt.title('Green NIGGI')
plt.colorbar()
plt.show()

# %%
plt.matshow(NIGGI[:,:,:])
plt.title('FULL NIGGI')
plt.colorbar()
plt.show()

# %%
import colorsys
(r,g,b)=NIGGA[:,:,0],NIGGA[:,:,1],NIGGA[:,:,2]
(h,s,v)=colorsys.rgb_to_hsv(r,g,b)

# %%
b
